# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
d1 = pd.read_csv('../data/data_1.csv')

# %%
d1
# Out:
#          name  age sex  body weight  ReactionTime  ChimpTest  VerbalMemory  \
# 0       chris   34   m         72.0           211         10            60
# 1       yewon   30   f         63.0           324         10            23
# 2     evaldas   25   m         73.0           209         11            40
# 3        radu   22   m         81.0           207          9            46
# 4       iulia   22   f         67.0           239         11            31
# 5      albert   22   m         65.0           214         18            17
# 6       chris   34   m         72.0           200          9            19
# 7     evaldas   25   m         73.0           188          9            53
# 8       yewon   30   f         63.0           261          9            15
# 9        radu   22   m         81.0           200         11            20
# 10     albert   22   m         65.0           215         10            19
# ...

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               49 non-null     object
#  1   age                49 non-null     int64
#  2   sex                49 non-null     object
#  3   body weight        49 non-null     float64
#  4   ReactionTime       49 non-null     int64
#  5   ChimpTest          49 non-null     int64
#  6   VerbalMemory       49 non-null     int64
#  7   Total Drink Count  49 non-null     float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 3.2+ KB

# %%
# Average of all reaction times when sober
r1 = d1[d1["Total Drink Count"] == 0]["ReactionTime"]
np.average(r1)
# Out:
# 222.84615384615384

# %%
# Average of all reaction times after the start of drinking
r2 = d1[d1["Total Drink Count"] > 0]["ReactionTime"]
np.average(r2)
# Out:
# 220.69444444444446

# %%
# Average of all reaction times after at least 4 drinks
r3 = d1[d1["Total Drink Count"] > 4]["ReactionTime"]
np.average(r3)
# Out:
# 227.33333333333334

# %%
####################

# %%
# Average of all chimp tests when sober
c1 = d1[d1["Total Drink Count"] == 0]["ChimpTest"]
np.average(c1)
# Out:
# 10.76923076923077

# %%
# Average of all chimp tests after the start of drinking
c2 = d1[d1["Total Drink Count"] > 0 ]["ChimpTest"]
np.average(c2)
# Out:
# 10.472222222222221

# %%
# Average of all chimp tests after at least 4 drinks
c3 = d1[d1["Total Drink Count"] > 4]["ChimpTest"]
np.average(c3)
# Out:
# 10.444444444444445

# %%
####################

# %%
# Average of all verbal memory tests when sober
m1 = d1[d1["Total Drink Count"] == 0]["VerbalMemory"]
np.average(m1)
# Out:
# 45.46153846153846

# %%
# Average of all verbal memory tests after the start of drinking
m2 = d1[d1["Total Drink Count"] > 0]["VerbalMemory"]
np.average(m2)
# Out:
# 32.666666666666664

# %%
# Average of all verbal memory tests after at least 4 drinks
m3 = d1[d1["Total Drink Count"] > 4]["VerbalMemory"]
np.average(m3)
# Out:
# 32.388888888888886
